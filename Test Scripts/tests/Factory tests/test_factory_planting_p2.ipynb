# %% [markdown]
# #### Classes to serialize commands

# %%
import json

# %%
class InputAction:
    def __init__(self, actionType, properties):
        self.ActionType = actionType
        self.Properties = properties
        
    def toJSON(self):
        return json.dumps(self, default=lambda obj: obj.__dict__)

# %%
class Action:
    def __init__(self, x = 0, y = 0, cardId = 0, amount = 0):
        self.X = x
        self.Y = y
        self.CardId = cardId
        self.Amount = amount

# %%
Actions = []
Actions.append(InputAction('L',[Action(x=6,y=7),Action(x=7,y=6),Action(x=6,y=6),]))
Actions.append(InputAction('C',[Action(cardId=0,amount=5),Action(cardId=3,amount=2)]))
Actions.append(InputAction('P',[Action(cardId=3,x=7,y=7),Action(cardId=3,x=7,y=6)]))
Actions.append(InputAction('W',[Action(amount=2,x=7,y=7),Action(amount=2,x=7,y=6)]))
Actions.append(InputAction('H',[]))

Actions.append(InputAction('C',[Action(cardId=0,amount=5),Action(cardId=3,amount=2)]))
Actions.append(InputAction('P',[Action(cardId=3,x=7,y=7),Action(cardId=3,x=7,y=6)]))
Actions.append(InputAction('W',[Action(amount=2,x=7,y=7),Action(amount=2,x=7,y=6)]))
Actions.append(InputAction('H',[]))

Actions.append(InputAction('C',[Action(cardId=0,amount=10),Action(cardId=5,amount=2)]))
Actions.append(InputAction('P',[Action(cardId=5,x=7,y=7),Action(cardId=5,x=7,y=6)]))
Actions.append(InputAction('W',[Action(amount=5,x=7,y=7),Action(amount=5,x=7,y=6)]))
Actions.append(InputAction('H',[]))

Actions.append(InputAction('C',[Action(cardId=0,amount=18),Action(cardId=6,amount=2)]))
Actions.append(InputAction('P',[Action(cardId=6,x=7,y=7),Action(cardId=6,x=7,y=6)]))
Actions.append(InputAction('W',[Action(amount=9,x=7,y=7),Action(amount=9,x=7,y=6)]))
Actions.append(InputAction('H',[]))

Actions.append(InputAction('C',[Action(cardId=1,amount=1),Action(cardId=2,amount=1)]))
Actions.append(InputAction('M',[Action(x=1,y=1)]))
Actions.append(InputAction('F',[Action(x=6,y=6)]))

#should execute
Actions.append(InputAction('P',[Action(cardId=3,x='6а',y=5),Action(cardId=3,x=5,y=6),Action(cardId=3,x=5,y=5),]))
Actions.append(InputAction('P',[Action(cardId=3,x='3а',y=5),Action(cardId=3,x=5,y=6),Action(cardId=3,x=5,y=5),]))
Actions.append(InputAction('P',[Action(cardId=3,x=6,y='3а'),Action(cardId=3,x=5,y=5),Action(cardId=3,x=6,y=5),]))
Actions.append(InputAction('P',[Action(cardId=3,x=6,y=8),   Action(cardId=3,x=7,y=5),Action(cardId=3,x=6,y=5),]))
Actions.append(InputAction('P',[Action(cardId=3,x=6,y=5),   Action(cardId=3,x=7,y=5),Action(cardId=3,x=6,y=8),]))
Actions.append(InputAction('P',[Action(cardId=3,x=8,y=5),   Action(cardId=3,x=7,y=5),Action(cardId=3,x=6,y=5),]))
Actions.append(InputAction('P',[Action(cardId=3,x=6,y=5),   Action(cardId=3,x=7,y=5),Action(cardId=3,x=8,y=5),]))

Actions.append(InputAction('P',[Action(cardId=0,x=7,y=7),Action(cardId=3,x=7,y=6),Action(cardId=3,x=6,y=6)]))
Actions.append(InputAction('P',[Action(cardId=1,x=7,y=7),Action(cardId=3,x=7,y=6),Action(cardId=3,x=6,y=6)]))
Actions.append(InputAction('P',[Action(cardId=2,x=7,y=7),Action(cardId=3,x=7,y=6),Action(cardId=3,x=6,y=6)]))

Actions.append(InputAction('P',[Action(x='1111111111111',y='1111111111111'),Action(x=7,y=6),Action(x=6,y=6),]))

# %%
a = InputAction('L',[Action(2147483647,2147483647,2147483647,2147483647) for i in range(0,64)]).toJSON()
len(a)
b = InputAction('L',[Action(-10,-10,-10,-10) for i in range(0,64)]).toJSON()

# %% [markdown]
# #### input

# %%
i = -1
def bot_input(dto):
    global i
    i+=1
    return Actions[i].toJSON()

# %%
PLAYER_NUM = 2
TEAM_NAME = 'TEAM 2'
AMOUNT_OF_GAMES = 1
RESTART = True
RESTART_TURN = len(Actions)+1
# %run "socket_script.ipynb"
