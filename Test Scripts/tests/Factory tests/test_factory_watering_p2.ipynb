# %% [markdown]
# #### Classes to serialize commands

# %%
import json

# %%
class InputAction:
    def __init__(self, actionType, properties):
        self.ActionType = actionType
        self.Properties = properties
        
    def toJSON(self):
        return json.dumps(self, default=lambda obj: obj.__dict__)

# %%
class Action:
    def __init__(self, x = 0, y = 0, cardId = 0, amount = 0):
        self.X = x
        self.Y = y
        self.CardId = cardId
        self.Amount = amount

# %%
Actions = []
Actions.append(InputAction('L',[Action(x=6,y=7),Action(x=7,y=6),Action(x=6,y=6),]))
Actions.append(InputAction('C',[Action(cardId=0,amount=5),Action(cardId=3,amount=2)]))
Actions.append(InputAction('P',[Action(cardId=3,x=7,y=7),Action(cardId=3,x=7,y=6)]))
Actions.append(InputAction('W',[Action(amount=2,x=7,y=7),Action(amount=2,x=7,y=6)]))
Actions.append(InputAction('H',[]))

Actions.append(InputAction('C',[Action(cardId=0,amount=5),Action(cardId=3,amount=2)]))
Actions.append(InputAction('P',[Action(cardId=3,x=7,y=7),Action(cardId=3,x=7,y=6)]))
Actions.append(InputAction('W',[Action(amount=2,x=7,y=7),Action(amount=2,x=7,y=6)]))
Actions.append(InputAction('H',[]))

Actions.append(InputAction('C',[Action(cardId=0,amount=10),Action(cardId=5,amount=2)]))
Actions.append(InputAction('P',[Action(cardId=5,x=7,y=7),Action(cardId=5,x=7,y=6)]))
Actions.append(InputAction('W',[Action(amount=5,x=7,y=7),Action(amount=5,x=7,y=6)]))
Actions.append(InputAction('H',[]))

Actions.append(InputAction('C',[Action(cardId=0,amount=18),Action(cardId=6,amount=2)]))
Actions.append(InputAction('P',[Action(cardId=6,x=7,y=7),Action(cardId=6,x=7,y=6)]))
Actions.append(InputAction('W',[Action(amount=9,x=7,y=7),Action(amount=9,x=7,y=6)]))
Actions.append(InputAction('H',[]))

Actions.append(InputAction('C',[Action(cardId=1,amount=1),Action(cardId=2,amount=1)]))
Actions.append(InputAction('M',[Action(x=1,y=1)]))
Actions.append(InputAction('F',[Action(x=6,y=6)]))
Actions.append(InputAction('W',[Action(x='6',y=5),Action(x=5,y=6),Action(x=5,y=5),]))
Actions.append(InputAction('W',[Action(x=4,y=5),Action(x=4,y='6'),Action(x=4,y=4),]))
Actions.append(InputAction('W',[Action(x=6,y=4),Action(x=5,y=4),Action(x='6',y=4),]))

test_actions = []
#should execute
test_actions.append(InputAction('W',[Action(x=-1,y=7),Action(x=7,y=6),Action(x=6,y=6),]))
test_actions.append(InputAction('W',[Action(x=6,y=7),Action(x=7,y=6),Action(x=-1,y=6),]))
test_actions.append(InputAction('W',[Action(x=6,y=7),Action(x=7,y=6),Action(x=6,y=-1),]))
test_actions.append(InputAction('W',[Action(x=6,y=-1),Action(x=7,y=6),Action(x=6,y=6),]))
test_actions.append(InputAction('W',[Action(x=1,y=8),Action(x=0,y=2),Action(x=1,y=2),]))
test_actions.append(InputAction('W',[Action(x=1,y=2),Action(x=0,y=2),Action(x=1,y=8),]))
test_actions.append(InputAction('W',[Action(x=8,y=2),Action(x=0,y=2),Action(x=1,y=2),]))
test_actions.append(InputAction('W',[Action(x=1,y=2),Action(x=0,y=2),Action(x=8,y=2),]))
test_actions.append(InputAction('W',[Action(x='1111111111111',y='1111111111111'),Action(x=7,y=6),Action(x=6,y=6),]))
test_actions.append(InputAction('W',[]))

Actions.extend(test_actions)
i=-1

# %% [markdown]
# #### input

# %%
last_dto = ''
def bot_input(dto):
    global i, last_dto
    i+=1
    if i >= RESTART_TURN-len(test_actions) and str(dto.source) != str(last_dto.source):
        print('[Watering factory test]error at turn: {}'.format(i))
        print('me: ' + str(dto.source))
        print('me before: ' + str(last_dto.source))
        last_dto = dto
    else:
        last_dto = dto
    return Actions[i].toJSON()

# %%
PLAYER_NUM = 2
TEAM_NAME = 'TEAM 2'
AMOUNT_OF_GAMES = 1
RESTART = True
RESTART_TURN = len(Actions)+1
# %run "socket_script.ipynb"
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Nikola\Documents\Unreal Projects\AI for game\tests\socket_script.ipynb in <module>
#       1 client = selectPlayer()
#       2 client.send(TEAM_NAME)
# ----> 3 client.receive()
#
# c:\Users\Nikola\Documents\Unreal Projects\AI for game\tests\socket_script.ipynb in receive(self)
#      29                         self.attempt_reconnect()
#      30                 else:
# ---> 31                     bot_msg = bot_input(dto)
#      32                     self.send(bot_msg)
#      33
#
# c:\Users\Nikola\Documents\Unreal Projects\AI for game\tests\socket_script.ipynb in bot_input(dto)
#       3     global i
#       4     i+=1
# ----> 5     return Actions[i].toJSON()
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# ...
