# %% [markdown]
# #### Imports

# %%
import time

# %% [markdown]
# #### Factory commands

# %%
# %run "Factory tests/test_factory_land_p2.ipynb"
time.sleep(1)
# %run "Factory tests/test_factory_watering_p2.ipynb"
time.sleep(1)
# %run "Factory tests/test_factory_mole_p2.ipynb"
time.sleep(1)
# %run "Factory tests/test_factory_buying_p2.ipynb"
time.sleep(1)
# %run "Factory tests/test_factory_planting_p2.ipynb"
time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# c:\Users\Nikola\Documents\Unreal Projects\AIBG20\Test Scripts\tests\Factory tests\socket_script.ipynb in <module>
#       1 client = selectPlayer()
#       2 client.send(TEAM_NAME)
# ----> 3 client.receive()
#
# c:\Users\Nikola\Documents\Unreal Projects\AIBG20\Test Scripts\tests\Factory tests\socket_script.ipynb in receive(self)
#      14     def receive(self):
#      15         for turn in range(1,RESTART_TURN+1):
# ---> 16             msg = self.client.recv(8)
#      17             msg = msg.decode(FORMAT)
#      18             try:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# c:\Users\Nikola\Documents\Unreal Projects\AIBG20\Test Scripts\tests\Factory tests\test_factory_watering_p2.ipynb in <module>
#       4 RESTART = True
#       5 RESTART_TURN = len(Actions)+1
# ----> 6 get_ipython().run_line_magic('run', '"socket_script.ipynb"')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2350             with self.builtin_trap:
# -> 2351                 result = fn(*args, **kwargs)
#    2352             return result
#    2353
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2836                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2837                     if raise_exceptions:
# -> 2838                         result.raise_error()
#    2839                     elif not result.success:
#    2840                         break
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in raise_error(self)
#     330             raise self.error_before_exec
#     331         if self.error_in_exec is not None:
# --> 332             raise self.error_in_exec
#     333
#     334     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# c:\Users\Nikola\Documents\Unreal Projects\AIBG20\Test Scripts\tests\Factory tests\test_factory_watering_p2.ipynb in <module>
#       1 client = selectPlayer()
#       2 client.send(TEAM_NAME)
# ----> 3 client.receive()
#
# c:\Users\Nikola\Documents\Unreal Projects\AIBG20\Test Scripts\tests\Factory tests\test_factory_watering_p2.ipynb in receive(self)
#      14     def receive(self):
#      15         for turn in range(1,RESTART_TURN+1):
# ---> 16             msg = self.client.recv(8)
#      17             msg = msg.decode(FORMAT)
#      18             try:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9820/2160977303.py in <module>
#       1 get_ipython().run_line_magic('run', '"Factory tests/test_factory_land_p2.ipynb"')
#       2 time.sleep(1)
# ----> 3 get_ipython().run_line_magic('run', '"Factory tests/test_factory_watering_p2.ipynb"')
#       4 time.sleep(1)
#       5 get_ipython().run_line_magic('run', '"Factory tests/test_factory_mole_p2.ipynb"')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2350             with self.builtin_trap:
# -> 2351                 result = fn(*args, **kwargs)
#    2352             return result
#    2353
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2836                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2837                     if raise_exceptions:
# -> 2838                         result.raise_error()
#    2839                     elif not result.success:
#    2840                         break
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in raise_error(self)
#     330             raise self.error_before_exec
#     331         if self.error_in_exec is not None:
# --> 332             raise self.error_in_exec
#     333
#     334     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp/ipykernel_9820/3210225610.py in <module>
#       4 RESTART = True
#       5 RESTART_TURN = len(Actions)+1
# ----> 6 get_ipython().run_line_magic('run', '"socket_script.ipynb"')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2350             with self.builtin_trap:
# -> 2351                 result = fn(*args, **kwargs)
#    2352             return result
#    2353
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2836                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2837                     if raise_exceptions:
# -> 2838                         result.raise_error()
#    2839                     elif not result.success:
#    2840                         break
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in raise_error(self)
#     330             raise self.error_before_exec
#     331         if self.error_in_exec is not None:
# --> 332             raise self.error_in_exec
#     333
#     334     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp/ipykernel_9820/3017917743.py in <module>
#       1 client = selectPlayer()
#       2 client.send(TEAM_NAME)
# ----> 3 client.receive()
#
# ~\AppData\Local\Temp/ipykernel_9820/1288151638.py in receive(self)
#      14     def receive(self):
#      15         for turn in range(1,RESTART_TURN+1):
# ---> 16             msg = self.client.recv(8)
#      17             msg = msg.decode(FORMAT)
#      18             try:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %% [markdown]
# #### Action commands

# %%
# %run "Command tests/test_command_land_p2.ipynb"
time.sleep(1)
# %run "Command tests/test_command_watering_p2.ipynb"
time.sleep(1)
# %run "Command tests/test_command_mole_p2.ipynb"
time.sleep(1)
# %run "Command tests/test_command_buying_p2.ipynb"
time.sleep(1)
# %run "Command tests/test_command_planting_p2.ipynb"
time.sleep(1)
# %run "Command tests/test_command_fertilizer_p2.ipynb"
time.sleep(1)
