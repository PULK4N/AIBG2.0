# %% [markdown]
# #### Classes to serialize commands

# %%
import json

# %%
class InputAction:
    def __init__(self, actionType, properties):
        self.ActionType = actionType
        self.Properties = properties
        
    def toJSON(self):
        return json.dumps(self, default=lambda obj: obj.__dict__)

# %%
class Action:
    def __init__(self, x = 0, y = 0, cardId = 0, amount = 0):
        self.X = x
        self.Y = y
        self.CardId = cardId
        self.Amount = amount

# %%
Actions = []
Actions.append(InputAction('L',[Action(x=6,y=7),Action(x=7,y=6),Action(x=6,y=6),]))
Actions.append(InputAction('C',[Action(cardId=0,amount=5),Action(cardId=3,amount=2)]))
Actions.append(InputAction('P',[Action(cardId=3,x=7,y=7),Action(cardId=3,x=7,y=6)]))
Actions.append(InputAction('W',[Action(amount=2,x=7,y=7),Action(amount=2,x=7,y=6)]))
Actions.append(InputAction('H',[]))

Actions.append(InputAction('C',[Action(cardId=0,amount=5),Action(cardId=3,amount=2)]))
Actions.append(InputAction('P',[Action(cardId=3,x=7,y=7),Action(cardId=3,x=7,y=6)]))
Actions.append(InputAction('W',[Action(amount=2,x=7,y=7),Action(amount=2,x=7,y=6)]))
Actions.append(InputAction('H',[]))

Actions.append(InputAction('C',[Action(cardId=0,amount=10),Action(cardId=5,amount=2)]))
Actions.append(InputAction('P',[Action(cardId=5,x=7,y=7),Action(cardId=5,x=7,y=6)]))
Actions.append(InputAction('W',[Action(amount=5,x=7,y=7),Action(amount=5,x=7,y=6)]))
Actions.append(InputAction('H',[]))

Actions.append(InputAction('C',[Action(cardId=0,amount=18),Action(cardId=6,amount=2)]))
Actions.append(InputAction('P',[Action(cardId=6,x=7,y=7),Action(cardId=6,x=7,y=6)]))
Actions.append(InputAction('W',[Action(amount=9,x=7,y=7),Action(amount=9,x=7,y=6)]))
Actions.append(InputAction('H',[]))

Actions.append(InputAction('F',[Action(x=6,y=6)]))
Actions.append(InputAction('C',[Action(cardId=1,amount=1),Action(cardId=2,amount=1)]))
Actions.append(InputAction('M',[Action(x=1,y=1)]))

test_actions = []
#invalid actions, should not execute because source owns tile
test_actions.append(InputAction('M',[Action(x=7,y=7)]))
#No one owns the tile
test_actions.append(InputAction('M',[Action(x=5,y=5)]))
#Have no money
test_actions.append(InputAction('C',[Action(cardId=6,amount=2),Action(cardId=0,amount=5),
                                Action(cardId=0,amount=5),Action(cardId=0,amount=5),Action(cardId=0,amount=5),Action(cardId=0,amount=5),
                                Action(cardId=0,amount=5),Action(cardId=0,amount=5),Action(cardId=0,amount=5),Action(cardId=0,amount=5),
                                Action(cardId=0,amount=5),Action(cardId=0,amount=5),Action(cardId=0,amount=5),Action(cardId=0,amount=5),
                                Action(cardId=0,amount=5),Action(cardId=0,amount=5),Action(cardId=0,amount=5),Action(cardId=0,amount=5),
                                Action(cardId=0,amount=5),Action(cardId=0,amount=5),Action(cardId=0,amount=5),Action(cardId=0,amount=5),]))

test_actions.append(InputAction('M',[Action(x=0,y=0)]))
Actions.extend(test_actions)

i=-1

# %% [markdown]
# #### input

# %%
last_dto = ''
def bot_input(dto):
    global i, last_dto
    i+=1
    if i >= RESTART_TURN-len(test_actions) and i != RESTART_TURN-2 and str(dto.source) != str(last_dto.source):
        print('[Mole factory test]\nerror at turn: {}'.format(i))
        print('me: ' + str(dto.source))
        print('me before: ' + str(last_dto.source))
        last_dto = dto
    else:
        last_dto = dto
    return Actions[i].toJSON()

# %%
PLAYER_NUM = 2
TEAM_NAME = 'TEAM 2'
AMOUNT_OF_GAMES = 1
RESTART = True
RESTART_TURN = len(Actions)+1
# %run "socket_script.ipynb"
# Out:
# [Mole factory test]
# error at turn: 21
# me:
# Gold = 7400, Points = 34000 Fertilizer active for 1 turns
# 	Coordinations = [7,7], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [6,7], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [7,6], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [1,1], planted =False, Special tile = True
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Owned 0 FERTILIZER_CARD
# 	Owned 0 MOLE_CARD
# 	Owned 30 WATER_CARD
# 	Owned 0 ANEMONE_FLOWERR_CARD
# 	Owned 0 BLUE_JAZZR_CARD
# 	Owned 0 CROCUS_FLOWERR_CARD
# 	Owned 0 TULIPR_CARD
#
# me before:
# Gold = 7400, Points = 34000 Fertilizer active for 2 turns
# 	Coordinations = [7,7], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [6,7], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [7,6], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [1,1], planted =False, Special tile = True
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Owned 0 FERTILIZER_CARD
# 	Owned 0 MOLE_CARD
# 	Owned 30 WATER_CARD
# 	Owned 0 ANEMONE_FLOWERR_CARD
# 	Owned 0 BLUE_JAZZR_CARD
# 	Owned 0 CROCUS_FLOWERR_CARD
# 	Owned 0 TULIPR_CARD
#
# [Mole factory test]
# error at turn: 22
# me:
# Gold = 7400, Points = 34000 Fertilizer active for 0 turns
# 	Coordinations = [7,7], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [6,7], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [7,6], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [1,1], planted =False, Special tile = True
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Owned 0 FERTILIZER_CARD
# 	Owned 0 MOLE_CARD
# 	Owned 30 WATER_CARD
# 	Owned 0 ANEMONE_FLOWERR_CARD
# 	Owned 0 BLUE_JAZZR_CARD
# 	Owned 0 CROCUS_FLOWERR_CARD
# 	Owned 0 TULIPR_CARD
#
# me before:
# Gold = 7400, Points = 34000 Fertilizer active for 1 turns
# 	Coordinations = [7,7], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [6,7], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [7,6], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [1,1], planted =False, Special tile = True
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Owned 0 FERTILIZER_CARD
# 	Owned 0 MOLE_CARD
# 	Owned 30 WATER_CARD
# 	Owned 0 ANEMONE_FLOWERR_CARD
# 	Owned 0 BLUE_JAZZR_CARD
# 	Owned 0 CROCUS_FLOWERR_CARD
# 	Owned 0 TULIPR_CARD
