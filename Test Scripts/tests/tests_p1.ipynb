# %% [markdown]
# #### Imports

# %%
import time

# %% [markdown]
# #### Factory commands

# %%
# %run "Factory tests/test_factory_land_p1.ipynb"
time.sleep(1)
# %run "Factory tests/test_factory_watering_p1.ipynb"
time.sleep(1)
# %run "Factory tests/test_factory_mole_p1.ipynb"
time.sleep(1)
# %run "Factory tests/test_factory_buying_p1.ipynb"
time.sleep(1)
#not working if playing vs AI
# %run "Factory tests/test_factory_planting_p1.ipynb"
time.sleep(1)

# %% [markdown]
# #### Action commands

# %%
# %run "Command tests/test_command_land_p1.ipynb"
time.sleep(1)
# %run "Command tests/test_command_watering_p1.ipynb"
time.sleep(1)
# %run "Command tests/test_command_mole_p1.ipynb"
time.sleep(1)
# %run "Command tests/test_command_buying_p1.ipynb"
time.sleep(1)
# %run "Command tests/test_command_planting_p1.ipynb"
time.sleep(1)
# %run "Command tests/test_command_fertilizer_p1.ipynb"
time.sleep(1)
