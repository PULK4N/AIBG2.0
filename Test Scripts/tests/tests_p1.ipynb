# %%
import time

# %%
# %run "Factory tests/test_factory_land_p1.ipynb"
#time.sleep(1)
#%run "Factory tests/test_factory_watering_p1.ipynb"
#time.sleep(1)
#%run "Factory tests/test_factory_mole_p1.ipynb"
#time.sleep(1)
#%run "Factory tests/test_factory_buying_p1.ipynb"
#time.sleep(1)
#%run "Factory tests/test_planting_buying_p1.ipynb"
#time.sleep(1)
# Out:
# me:
# Gold = 24400, Points = 34000 Fertilizer active for 0 turns
# 	Coordinations = [0,0], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [1,0], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [0,1], planted =False, Special tile = True
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [6,6], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Owned 0 FERTILIZER_CARD
# 	Owned 0 MOLE_CARD
# 	Owned 30 WATER_CARD
# 	Owned 0 ANEMONE_FLOWERR_CARD
# 	Owned 0 BLUE_JAZZR_CARD
# 	Owned 0 CROCUS_FLOWERR_CARD
# 	Owned 0 TULIPR_CARD
#
# enemy:
# Gold = 24400, Points = 34000 Fertilizer active for 0 turns
# 	Coordinations = [7,7], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# 	Coordinations = [6,7], planted =False, Special tile = False
# 		None, GoldWorth = 0, Water needed = 0
#
#
# ...
